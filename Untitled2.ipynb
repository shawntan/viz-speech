# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import matplotlib.cm as cm
import matplotlib
matplotlib.rcParams['savefig.dpi'] = 5*matplotlib.rcParams['savefig.dpi']

# %%
def display_patches(patches,overlay=None,filename=None):
    patches = patches.T.reshape((20,25,28,28))
    rows = [np.hstack(r) for r in patches]
    image = np.vstack(rows) 
    print np.min(image),np.max(image)
    plt.axis('off')
    plt.imshow(image,cmap=cm.gray,vmin=0.5*np.min(image),vmax=0.5*np.max(image),interpolation="nearest")
    if overlay is not None:
        cmap2 = cm.Reds
        alphas = np.linspace(0, 0.8, cmap2.N+3)
        cmap2._lut[:,-1] = alphas
        plt.imshow(overlay,cmap=cmap2,interpolation="nearest")
    if filename:
        plt.savefig(filename)

# %%
display_patches(pickle.load(open('patches.orig')))
# Out:
# -0.535482 0.481596

# %%
display_patches(pickle.load(open('patches.const')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-588a56ec906f> in <module>()
# ----> 1 display_patches(pickle.load(open('patches.const')))
#
# <ipython-input-2-0993d7945494> in display_patches(patches, overlay, filename)
#       1 def display_patches(patches,overlay=None,filename=None):
# ----> 2     patches = patches.T.reshape((20,25,28,28))
#       3     rows = [np.hstack(r) for r in patches]
#       4     image = np.vstack(rows)
#       5     print np.min(image),np.max(image)
#
# AttributeError: 'list' object has no attribute 'T'

# %%
data = pickle.load(open('mnist.pkl'))
images_all,labels = data[2]
def sigmoid(z): return 1.0 / (1.0 + np.exp(-z))

# %%
from scipy import misc
from collections import Counter
weights_const = pickle.load(open('full.const'))
weights_free = pickle.load(open('full.free'))

def plot_activations(weights,lbl):
    def hidden_layer(X):
        return sigmoid(np.dot(X,weights[0]) + weights[1])
    images = images_all[labels==lbl]
    activations = hidden_layer(images)

    total_activations = (activations).mean(axis=0)
    activations = total_activations.reshape((20,25))
    display_patches(weights[0],misc.imresize(activations,(20*28,25*28),interp="nearest"))
    #display_patches(weights[0])
    
plot_activations(weights_free,1)
# Out:
# -1.11664 1.04237
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-6e421dc4afd7> in <module>()
#      15     #display_patches(weights[0])
#      16
# ---> 17 plot_activations(weights_free,1)
#
# <ipython-input-21-6e421dc4afd7> in plot_activations(weights, lbl)
#      12     total_activations = (activations).mean(axis=0)
#      13     activations = total_activations.reshape((20,25))
# ---> 14     display_patches(weights[0],misc.imresize(activations,(20*28,25*28),interp="nearest"))
#      15     #display_patches(weights[0])
#      16
#
# <ipython-input-20-e0076f286159> in display_patches(patches, overlay, filename)
#       9         cmap2 = cm.Reds
#      10         alphas = np.linspace(0, 0.8, cmap2.N+3)
# ---> 11         cmap2._lut[:,-1] = alphas
#      12         plt.imshow(overlay,cmap=cmap2,interpolation="nearest")
#      13     if filename:
#
# ...

# %%
    fired_neuron = 334
    select = activations[:,fired_neuron]>0.5
    activations = activations[select]

    labels = labels[select]
    print "Breakdown:",Counter(labels)
    print "Activation %:",activations.shape[0]/float(images.shape[0])
    print "Activated mean:", activations[:,fired_neuron].mean()
# Out:
#   File "<ipython-input-22-583a2ce23c33>", line 2
#     fired_neuron = 334
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# $$ g(x,y) = \frac{1}{2\pi \sigma^2} \cdot e^{-\frac{x^2 + y^2}{2 \sigma^2}} $$
#
# $$ W = \left[ \right]$$
